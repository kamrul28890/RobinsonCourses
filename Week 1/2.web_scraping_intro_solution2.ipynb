# %%
#!pip install requests
#!pip install beautifulsoup4
#!pip install pandas

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
titles = []
prices = []
descriptions = []
ratings = []
url = 'https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops'
request = requests.get(url)

# %%
#request.text

# %%
soup = BeautifulSoup(request.text, "html.parser")

for product in soup.find_all('div', {'class': 'col-md-4 col-xl-4 col-lg-4'}):
    for pr in product.find_all('div', {'class': 'caption'}):
        for p in pr.find_all('h4', {'class': 'float-end price card-title pull-right'}):
            prices.append(p.text)
        for title in pr.find_all('a' , {'title'}):
            titles.append(title.get('title'))
        for desc in pr.find_all('p',{'class':'description'}):
            descriptions.append(desc.text)
    for rt in product.find_all('div', {'class': 'ratings'}):
        for rating in rt.find_all('p', attrs={'data-rating': True}):
            ratings.append(rating.get('data-rating'))
    
#add your own code to get the product description and product ratings, then export all information to csv
    
#build dataframe and export to csv            
product_df = pd.DataFrame(zip(titles,prices,descriptions,ratings), columns =['Titles', 'Prices', 'Description', 'Rating'])  
product_df.head()
# Out:
#                                Titles   Prices  \
# 0          Asus VivoBook X441NA-GA190  $295.99
# 1  Prestigio SmartBook 133S Dark Grey     $299
# 2       Prestigio SmartBook 133S Gold     $299
# 3                       Aspire E1-510  $306.99
# 4                   Lenovo V110-15IAP  $321.94
#
#                                          Description Rating
# 0  Asus VivoBook X441NA-GA190 Chocolate Black, 14...      3
# 1  Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...      2
# 2  Prestigio SmartBook 133S Gold, 13.3" FHD IPS, ...      4
# 3    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux      3
# 4  Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1...      3

# %%
product_df.to_csv("ecommerce.csv",index=False)

# %% [markdown]
# ## Go Ahead
# ### Next：Read Data
# * 1. load data
# * 2. show columns

# %%
pd.read_csv('ecommerce.csv')
# Out:
#                                          Titles    Prices  \
# 0                    Asus VivoBook X441NA-GA190   $295.99
# 1            Prestigio SmartBook 133S Dark Grey   $299.00
# 2                 Prestigio SmartBook 133S Gold   $299.00
# 3                                 Aspire E1-510   $306.99
# 4                             Lenovo V110-15IAP   $321.94
# ..                                          ...       ...
# 229                          Lenovo Legion Y720  $1399.00
# 230               Asus ROG Strix GL702VM-GC146T  $1399.00
# 231               Asus ROG Strix GL702ZC-GC154T  $1769.00
# 232               Asus ROG Strix GL702ZC-GC209T  $1769.00
# 233  Asus ROG Strix SCAR Edition GL503VM-ED115T  $1799.00
#
#                                            Description  Rating
# 0    Asus VivoBook X441NA-GA190 Chocolate Black, 14...       3
# 1    Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...       2
# 2    Prestigio SmartBook 133S Gold, 13.3" FHD IPS, ...       4
# 3      15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux       3
# 4    Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1...       3
# ..                                                 ...     ...
# 229  Lenovo Legion Y720, 15.6" FHD IPS, Core i7-770...       3
# 230  Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core...       3
# 231  Asus ROG Strix GL702ZC-GC154T, 17.3" FHD, Ryze...       4
# 232  Asus ROG Strix GL702ZC-GC209T, 17.3" FHD IPS, ...       1
# 233  Asus ROG Strix SCAR Edition GL503VM-ED115T, 15...       3
#
# [234 rows x 4 columns]
